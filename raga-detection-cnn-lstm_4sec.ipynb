# %%
import numpy as np 
import pandas as pd
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import librosa
import librosa.display
import IPython.display as ipd
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import Adam
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import ModelCheckpoint
from datetime import datetime
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, LSTM, BatchNormalization
from sklearn.metrics import confusion_matrix, f1_score, classification_report
from scipy.io import wavfile as wav
from keras.models import load_model
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
audio1= "D:/Joy/Research_Joy/Music_Research/all_dataset/4s_clips/Karaharapriya_1.wav"

# %%
data,sr1=librosa.load(audio1)
ipd.Audio(audio1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(data)
plt.xlabel('Audio 1')
plt.ylabel('Amplitude')
plt.show()

# %%
wavesr2, wave_audio=wav.read(audio1)

# %%
wavesr2
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[   0,    0],
#        [   0,    0],
#        [   0,    0],
#        ...,
#        [1062, 3025],
#        [1049, 2969],
#        [1040, 2916]], dtype=int16)

# %%
plt.plot(wave_audio)
plt.show()

# %%
folder_path = 'D:/Joy/Research_Joy/Music_Research/all_dataset/4s_clips'
file_names = [file for file in os.listdir(folder_path) if file.endswith('.wav')]

# Extract the text before '_' for each file name
raga_name = [name.split('_')[0] for name in file_names]

print(raga_name)
# Out:
# ['Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Kar ...

# %%
print(file_names[:5])
print(raga_name[:5])
# Out:
# ['Karaharapriya_1.wav', 'Karaharapriya_10.wav', 'Karaharapriya_100.wav', 'Karaharapriya_1000.wav', 'Karaharapriya_1001.wav']
# ['Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya', 'Karaharapriya']

# %%
def features_extractor(file_or_audio, sample_rate=None):
    if isinstance(file_or_audio, str):
        audio, sample_rate = librosa.load(file_or_audio)
    else:
        audio = file_or_audio

    mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs.T, axis=0)
    return mfccs_scaled_features

# %%
extracted_features = []
for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    features = features_extractor(file_path)
    file_name = file_name.title()
    extracted_features.append([features, file_name.split('_')[0]])
print(extracted_features)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
features_df=pd.DataFrame(extracted_features,columns=['feature','class'])
features_df.head()
# Out:
#                                              feature          class
# 0  [-326.66315, 150.1236, 12.368341, 11.485236, -...  Karaharapriya
# 1  [-20.414864, 90.306595, -53.618507, 30.440435,...  Karaharapriya
# 2  [-157.26318, 84.28332, -8.102835, 66.71092, -4...  Karaharapriya
# 3  [-146.22266, 50.805264, -63.31208, 31.665962, ...  Karaharapriya
# 4  [-159.23874, 39.086502, -54.26132, 28.372612, ...  Karaharapriya

# %%
X=np.array(features_df['feature'].tolist())
y=np.array(features_df['class'].tolist())
le=LabelEncoder()
ti=le.fit_transform(y)
y=to_categorical(ti)

# %%
y.shape
# Out:
# (18285, 5)

# %%
originallabels=le.classes_
print("Original labels: ", originallabels)
print("Encoded labels: ", np.unique(ti))
# Out:
# Original labels:  ['Karaharapriya' 'Keeravani' 'Sarasangi' 'Shanmugapriya' 'Thodi']
# Encoded labels:  [0 1 2 3 4]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=127)

# %%
X_train.shape
# Out:
# (14628, 40)

# %%
y_train.shape
# Out:
# (14628, 5)

# %%
X_train.shape
# Out:
# (14628, 40)

# %%
y_test.shape
# Out:
# (3657, 5)

# %%
num_labels = y.shape[1]
print(num_labels)
# Out:
# 5

# %%
X_train_flat = np.array([x.flatten() for x in X_train])
X_test_flat = np.array([x.flatten() for x in X_train])

# %%
num_classes = 5
model = Sequential()
model.add(Conv1D(64, kernel_size=5, activation='relu', input_shape=(X_train_flat.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Conv1D(128, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# D:\Joy\Research_Joy\Music_Research\venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 36, 64)              │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 18, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 18, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 14, 128)             │          41,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 7, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 7, 128)              │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 7, 128)              │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          16,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │           1,285 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 241,157 (942.02 KB)
#  Trainable params: 240,773 (940.52 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='Adam')

# %%
num_classes = 5
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

num_epochs = 30
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_model_4s.keras', verbose=1, save_best_only=True)

start = datetime.now()
model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, 
          validation_data=(X_test, y_test), verbose=1, callbacks=[checkpointer])

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/30
# 457/458 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6437 - loss: 0.9231
# Epoch 1: val_loss improved from inf to 0.31760, saving model to saved_model_4s.keras
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - accuracy: 0.6443 - loss: 0.9217 - val_accuracy: 0.8939 - val_loss: 0.3176
# Epoch 2/30
# 457/458 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9067 - loss: 0.2740
# Epoch 2: val_loss improved from 0.31760 to 0.17674, saving model to saved_model_4s.keras
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9067 - loss: 0.2738 - val_accuracy: 0.9398 - val_loss: 0.1767
# Epoch 3/30
# 456/458 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9579 - loss: 0.1362
# Epoch 3: val_loss improved from 0.17674 to 0.17223, saving model to saved_model_4s.keras
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9579 - loss: 0.1362 - val_accuracy: 0.9420 - val_loss: 0.1722
# Epoch 4/30
# 457/458 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9605 - loss: 0.1182
# Epoch 4: val_loss improved from 0.17223 to 0.08807, saving model to saved_model_4s.keras
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9605 - loss: 0.1181 - val_accuracy: 0.9762 - val_loss: 0.0881
# Epoch 5/30
# 456/458 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9799 - loss: 0.0660
# Epoch 5: val_loss did not improve from 0.08807
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9799 - loss: 0.0660 - val_accuracy: 0.9688 - val_loss: 0.1065
# Epoch 6/30
# 456/458 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9830 - loss: 0.0538
# Epoch 6: val_loss improved from 0.08807 to 0.08132, saving model to saved_model_4s.keras
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9830 - loss: 0.0539 - val_accuracy: 0.9779 - val_loss: 0.0813
# Epoch 7/30
# 457/458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9839 - loss: 0.0455
# Epoch 7: val_loss did not improve from 0.08132
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9839 - loss: 0.0455 - val_accuracy: 0.9642 - val_loss: 0.1297
# Epoch 8/30
# 456/458 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9849 - loss: 0.0457
# Epoch 8: val_loss did not improve from 0.08132
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9849 - loss: 0.0457 - val_accuracy: 0.9721 - val_loss: 0.1003
# Epoch 9/30
# 457/458 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9810 - loss: 0.0597
# Epoch 9: val_loss did not improve from 0.08132
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9810 - loss: 0.0596 - val_accuracy: 0.9746 - val_loss: 0.0835
# Epoch 10/30
# 456/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9837 - loss: 0.0538
# Epoch 10: val_loss did not improve from 0.08132
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9837 - loss: 0.0538 - val_accuracy: 0.9710 - val_loss: 0.1013
# Epoch 11/30
# 453/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9824 - loss: 0.0590
# Epoch 11: val_loss did not improve from 0.08132
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9825 - loss: 0.0587 - val_accuracy: 0.9768 - val_loss: 0.0846
# Epoch 12/30
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9878 - loss: 0.0379
# Epoch 12: val_loss did not improve from 0.08132
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9878 - loss: 0.0379 - val_accuracy: 0.9787 - val_loss: 0.0904
# Epoch 13/30
# 453/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9869 - loss: 0.0406
# Epoch 13: val_loss did not improve from 0.08132
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9869 - loss: 0.0405 - val_accuracy: 0.9740 - val_loss: 0.0924
# Epoch 14/30
# 457/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9900 - loss: 0.0344
# Epoch 14: val_loss did not improve from 0.08132
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9900 - loss: 0.0344 - val_accuracy: 0.9737 - val_loss: 0.0973
# Epoch 15/30
# 453/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - loss: 0.0274
# Epoch 15: val_loss improved from 0.08132 to 0.06129, saving model to saved_model_4s.keras
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9917 - loss: 0.0274 - val_accuracy: 0.9836 - val_loss: 0.0613
# Epoch 16/30
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9912 - loss: 0.0264
# Epoch 16: val_loss did not improve from 0.06129
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9912 - loss: 0.0264 - val_accuracy: 0.9803 - val_loss: 0.0776
# Epoch 17/30
# 457/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9933 - loss: 0.0195
# Epoch 17: val_loss did not improve from 0.06129
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9933 - loss: 0.0195 - val_accuracy: 0.9787 - val_loss: 0.0773
# Epoch 18/30
# 455/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9906 - loss: 0.0289
# Epoch 18: val_loss improved from 0.06129 to 0.05778, saving model to saved_model_4s.keras
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9906 - loss: 0.0289 - val_accuracy: 0.9847 - val_loss: 0.0578
# Epoch 19/30
# 456/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9921 - loss: 0.0255
# Epoch 19: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9921 - loss: 0.0255 - val_accuracy: 0.9773 - val_loss: 0.1041
# Epoch 20/30
# 455/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9833 - loss: 0.0576
# Epoch 20: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9833 - loss: 0.0574 - val_accuracy: 0.9795 - val_loss: 0.0826
# Epoch 21/30
# 453/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9941 - loss: 0.0195
# Epoch 21: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9941 - loss: 0.0195 - val_accuracy: 0.9839 - val_loss: 0.0647
# Epoch 22/30
# 456/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9971 - loss: 0.0095
# Epoch 22: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9971 - loss: 0.0095 - val_accuracy: 0.9773 - val_loss: 0.1043
# Epoch 23/30
# 457/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9927 - loss: 0.0268
# Epoch 23: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9927 - loss: 0.0268 - val_accuracy: 0.9754 - val_loss: 0.0866
# Epoch 24/30
# 455/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9916 - loss: 0.0270
# Epoch 24: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9916 - loss: 0.0269 - val_accuracy: 0.9743 - val_loss: 0.0910
# Epoch 25/30
# 453/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9906 - loss: 0.0264
# Epoch 25: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9906 - loss: 0.0263 - val_accuracy: 0.9844 - val_loss: 0.0671
# Epoch 26/30
# 453/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9941 - loss: 0.0177
# Epoch 26: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9941 - loss: 0.0177 - val_accuracy: 0.9841 - val_loss: 0.0616
# Epoch 27/30
# 457/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9961 - loss: 0.0120
# Epoch 27: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9961 - loss: 0.0120 - val_accuracy: 0.9814 - val_loss: 0.0732
# Epoch 28/30
# 453/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9961 - loss: 0.0121
# Epoch 28: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9961 - loss: 0.0121 - val_accuracy: 0.9817 - val_loss: 0.0653
# Epoch 29/30
# 457/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9942 - loss: 0.0183
# Epoch 29: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9942 - loss: 0.0183 - val_accuracy: 0.9839 - val_loss: 0.0649
# Epoch 30/30
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9966 - loss: 0.0130
# Epoch 30: val_loss did not improve from 0.05778
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9966 - loss: 0.0131 - val_accuracy: 0.9828 - val_loss: 0.0678
# Training completed in time:  0:02:59.153635

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(f"test set accuracy: {test_accuracy[1] * 100}%")

train_accuracy=model.evaluate(X_train,y_train,verbose=0)
print(f"train set accuracy: {train_accuracy[1] * 100}%")
# Out:
# test set accuracy: 98.27727675437927%
# train set accuracy: 99.58983063697815%

# %%
saved_model = load_model('saved_model_4s.keras')
np.save('label_encoder_classes_ragas_4s.npy', le.classes_)

# %%
y_pred = saved_model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
conf_matrix = confusion_matrix(y_true, y_pred_classes)
f1 = f1_score(y_true, y_pred_classes, average='weighted')
print("Confusion Matrix:")
print(conf_matrix)

print("\nF1 Score:")
print(f1)

print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes, target_names=originallabels))
# Out:
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Confusion Matrix:
# [[713   0   5   0   3]
#  [  0 684   0   0   0]
#  [  4   1 758   1   4]
#  [  3   3   7 720   4]
#  [  3   4   9   5 726]]
#
# F1 Score:
# 0.9846736810574259
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Karaharapriya       0.99      0.99      0.99       721
#     Keeravani       0.99      1.00      0.99       684
#     Sarasangi       0.97      0.99      0.98       768
# Shanmugapriya       0.99      0.98      0.98       737
#         Thodi       0.99      0.97      0.98       747
#
#      accuracy                           0.98      3657
#     macro avg       0.98      0.98      0.98      3657
#  weighted avg       0.98      0.98      0.98      3657

# %%
file ="D:/Joy/Research_Joy/Music_Research/all_dataset/4s_clips/Karaharapriya_1.wav"
x,sr1 = librosa.load(file)
ipd.Audio(x,rate=sr1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
prediction_feature = features_extractor(file)
prediction_feature = prediction_feature.reshape(1,-1)
predicted_probabilities = model.predict(prediction_feature)
predicted_class_label = np.argmax(predicted_probabilities)
predicted_class_label = np.array([predicted_class_label])

prediction_class = le.inverse_transform(predicted_class_label)
print("Predicted class:", prediction_class[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# Predicted class: Karaharapriya
